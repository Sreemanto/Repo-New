# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
cn = pd.read_csv('https://raw.githubusercontent.com/Sreemanto/SK__007/master/countries.csv')

# %%
cn.head(4)
# Out:
#    Unnamed: 0      country continent  year  lifeExpectancy  population  \
# 0           0  Afghanistan      Asia  1952          28.801     8425333
# 1           1  Afghanistan      Asia  1957          30.332     9240934
# 2           2  Afghanistan      Asia  1962          31.997    10267083
# 3           3  Afghanistan      Asia  1967          34.020    11537966
#
#    gdpPerCapita
# 0    779.445314
# 1    820.853030
# 2    853.100710
# 3    836.197138

# %%
data_2007 = cn[cn['year']==2007]

# %% [markdown]
# ## Scatter Plot

# %%
#plt.scatter(x,y)
plt.scatter(data_2007['gdpPerCapita'],data_2007['lifeExpectancy'],s=20,c='tomato')

plt.title('Life Expectancy vs GDP Per Capita in 2007')

plt.xlabel('GDP per Capita($)')

plt.ylabel('Life Expectancy')

plt.show()

# %%
plt.scatter(np.log10(data_2007['gdpPerCapita']),data_2007['lifeExpectancy'])
plt.title('Life Expectancy vs GDP Per Capita in 2007 ')
plt.xlabel('GDP per Capita($)')
plt.ylabel('Life Expectancy')
plt.show()

# %% [markdown]
# ## Bar plot

# %%
data_2007.sort_values('population',ascending=False).head(10)
# Out:
#       Unnamed: 0        country continent  year  lifeExpectancy  population  \
# 299          299          China      Asia  2007          72.961  1318683096
# 707          707          India      Asia  2007          64.698  1110396331
# 1619        1619  United States  Americas  2007          78.242   301139947
# 719          719      Indonesia      Asia  2007          70.650   223547000
# 179          179         Brazil  Americas  2007          72.390   190010647
# 1175        1175       Pakistan      Asia  2007          65.483   169270617
# 107          107     Bangladesh      Asia  2007          64.062   150448339
# 1139        1139        Nigeria    Africa  2007          46.859   135031164
# 803          803          Japan      Asia  2007          82.603   127467972
# 995          995         Mexico  Americas  2007          76.195   108700891
#
#       gdpPerCapita
# 299    4959.114854
# 707    2452.210407
# 1619  42951.653090
# 719    3540.651564
# 179    9065.800825
# 1175   2605.947580
# 107    1391.253792
# 1139   2013.977305
# 803   31656.068060
# 995   11977.574960

# %%
top_10_p = data_2007.sort_values('population',ascending=False).head(10)
top_10_p
# Out:
#       Unnamed: 0        country continent  year  lifeExpectancy  population  \
# 299          299          China      Asia  2007          72.961  1318683096
# 707          707          India      Asia  2007          64.698  1110396331
# 1619        1619  United States  Americas  2007          78.242   301139947
# 719          719      Indonesia      Asia  2007          70.650   223547000
# 179          179         Brazil  Americas  2007          72.390   190010647
# 1175        1175       Pakistan      Asia  2007          65.483   169270617
# 107          107     Bangladesh      Asia  2007          64.062   150448339
# 1139        1139        Nigeria    Africa  2007          46.859   135031164
# 803          803          Japan      Asia  2007          82.603   127467972
# 995          995         Mexico  Americas  2007          76.195   108700891
#
#       gdpPerCapita
# 299    4959.114854
# 707    2452.210407
# 1619  42951.653090
# 719    3540.651564
# 179    9065.800825
# 1175   2605.947580
# 107    1391.253792
# 1139   2013.977305
# 803   31656.068060
# 995   11977.574960

# %%
top_10_p['country']
# Out:
# 299             China
# 707             India
# 1619    United States
# 719         Indonesia
# 179            Brazil
# 1175         Pakistan
# 107        Bangladesh
# 1139          Nigeria
# 803             Japan
# 995            Mexico
# Name: country, dtype: object

# %%
plt.figure(figsize=(12,6))

x=range(10)

plt.bar(x,top_10_p['population']) #x -- used to assign positions to the bar

#plt.xticks(x,top_10_p['country']) #xticks --- used to assign labels to the bars

plt.xlabel('Countries')
plt.ylabel('Population in Billions')
plt.title('10 Most Populous Countries in 2007')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
df = pd.read_csv('https://raw.githubusercontent.com/BadreeshShetty/Data-Visualization-using-Matplotlib/master/datasets/exams.csv')

# %%
#df.to_csv('Exams.csv',index=False)

# %%
df.head(4)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group C            some high school  free/reduced
# 1  female        group C                some college  free/reduced
# 2    male        group A                 high school      standard
# 3    male        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          69             61             58
# 1               completed          47             65             69
# 2                    none          66             52             53
# 3                    none          88             89             82

# %%
exam_scores = df[['math score', 'reading score', 'writing score']]
exam_scores.head()
# Out:
#    math score  reading score  writing score
# 0          69             61             58
# 1          47             65             69
# 2          66             52             53
# 3          88             89             82
# 4          62             82             76

# %%
exam_scores.describe()
# Out:
#        math score  reading score  writing score
# count  100.000000     100.000000     100.000000
# mean    67.150000      69.180000      67.780000
# std     12.797865      13.832607      14.874954
# min     36.000000      34.000000      33.000000
# 25%     56.000000      60.000000      57.750000
# 50%     68.000000      69.000000      68.500000
# 75%     76.000000      80.000000      77.250000
# max     95.000000      99.000000     100.000000

# %%
# For plotting in boxplot, we convert it to an array
exam_scores_array = np.array(exam_scores)
exam_scores_array
# Out:
# array([[ 69,  61,  58],
#        [ 47,  65,  69],
#        [ 66,  52,  53],
#        [ 88,  89,  82],
#        [ 62,  82,  76],
#        [ 47,  69,  60],
#        [ 71,  66,  74],
#        [ 57,  62,  60],
#        [ 60,  67,  65],
#        [ 74,  72,  76],
#        [ 77,  71,  67],
#        [ 69,  79,  83],
#        [ 65,  62,  56],
#        [ 55,  58,  51],
#        [ 78,  88,  91],
#        [ 70,  72,  72],
#        [ 55,  69,  55],
#        [ 68,  68,  62],
#        [ 73,  62,  58],
#        [ 54,  50,  51],
#        [ 81,  76,  77],
#        [ 70,  76,  73],
#        [ 64,  62,  63],
#        [ 51,  66,  63],
#        [ 49,  50,  43],
#        [ 83,  80,  82],
#        [ 86,  92,  81],
#        [ 83,  89,  94],
#        [ 61,  77,  68],
#        [ 55,  50,  44],
#        [ 56,  59,  55],
#        [ 46,  57,  61],
#        [ 68,  60,  52],
#        [ 78,  75,  69],
#        [ 85,  94,  93],
#        [ 95,  99,  95],
#        [ 82,  74,  78],
#        [ 94,  85,  96],
#        [ 64,  71,  68],
#        [ 70,  80,  85],
#        [ 84,  78,  84],
#        [ 62,  81,  73],
#        [ 52,  58,  53],
#        [ 89,  72,  74],
#        [ 64,  63,  63],
#        [ 74,  77,  72],
#        [ 50,  54,  54],
#        [ 86,  76,  82],
#        [ 53,  62,  64],
#        [ 36,  35,  33],
#        [ 64,  81,  75],
#        [ 71,  69,  74],
#        [ 73,  79,  77],
#        [ 80,  81,  72],
#        [ 75,  66,  67],
#        [ 64,  57,  51],
#        [ 68,  87,  77],
#        [ 73,  60,  65],
#        [ 77,  76,  69],
#        [ 85,  89,  85],
#        [ 77,  85,  82],
#        [ 53,  70,  72],
#        [ 48,  43,  42],
#        [ 91,  91, 100],
#        [ 67,  81,  85],
#        [ 74,  87,  88],
#        [ 70,  82,  78],
#        [ 65,  56,  58],
#        [ 75,  67,  63],
#        [ 63,  56,  49],
#        [ 86,  92,  94],
#        [ 76,  87,  85],
#        [ 56,  62,  67],
#        [ 48,  61,  64],
#        [ 67,  62,  60],
#        [ 80,  86,  88],
#        [ 77,  73,  74],
#        [ 51,  58,  53],
#        [ 71,  80,  84],
#        [ 59,  67,  72],
#        [ 69,  62,  57],
#        [ 74,  71,  71],
#        [ 63,  68,  65],
#        [ 68,  54,  50],
#        [ 69,  79,  73],
#        [ 75,  86,  89],
#        [ 79,  81,  74],
#        [ 51,  36,  44],
#        [ 59,  60,  56],
#        [ 49,  55,  49],
#        [ 76,  76,  69],
#        [ 75,  78,  77],
#        [ 54,  45,  43],
#        [ 45,  63,  65],
#        [ 75,  75,  78],
#        [ 56,  59,  61],
#        [ 64,  57,  62],
#        [ 62,  48,  38],
#        [ 44,  34,  36],
#        [ 48,  48,  40]], dtype=int64)

# %%
plt.boxplot(exam_scores_array, patch_artist=True,notch=True)
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
plt.violinplot(exam_scores_array,showmedians=True)

plt.show()

# %% [markdown]
# ## Histogram

# %%
np_data = pd.read_csv('https://raw.githubusercontent.com/BadreeshShetty/Data-Visualization-using-Matplotlib/master/datasets/national_parks.csv')

# %%
#np_data.to_csv('national_parks.csv',index=False)

# %%
np_data
# Out:
#     Year  Badlands  GrandCanyon  BryceCanyon
# 0   1961    833300      1253000       264800
# 1   1962   1044800      1447400       251000
# 2   1963   1074000      1539500       289500
# 3   1964   1079800      1576600       300300
# 4   1965   1091300      1689200       366800
# 5   1966   1094800      1806000       396600
# 6   1967   1188700      1804900       295000
# 7   1968   1194600      1986300       320800
# 8   1969   1221300      2192600       366900
# 9   1970   1303100      2258200       345900
# 10  1971   1282000      2402100       377800
# 11  1972   1274600      2698300       424830
# 12  1973   1387900      1909700       429700
# 13  1974   1205300      1888600       408800
# 14  1975   1153200      2625100       579200
# 15  1976   1210100      2791600       625600
# 16  1977   1305400      2627200       611500
# 17  1978   1234915      2748642       679260
# 18  1979    858000      2131716       558095
# 19  1980    952652      2304973       571541
# 20  1981   1175952      2472270       474092
# 21  1982   1030484      2293127       471517
# 22  1983   1026981      2248082       472633
# 23  1984   1113675      2173584       495104
# 24  1985    950242      2711529       500782
# 25  1986   1025630      3035787       578018
# 26  1987   1174398      3513030       718342
# 27  1988   1110040      3859886       791348
# 28  1989   1237956      3966209       808045
# 29  1990   1326475      3776685       862659
# 30  1991   1518396      3886031       929067
# 31  1992   1205297      4203545      1018174
# 32  1993   1179458      4575602      1107951
# 33  1994   1130459      4364316      1028134
# 34  1995   1075569      4557645       994548
# 35  1996   1024705      4537703      1269600
# 36  1997    970696      4791668      1174824
# 37  1998   1021049      4239682      1166331
# 38  1999    950453      4575124      1081521
# 39  2000   1105824      4460228      1099275
# 40  2001    955469      4104809      1068619
# 41  2002    908898      4001974       886436
# 42  2003    871034      4124900       903760
# 43  2004    936030      4326234       987253
# 44  2005    909146      4401522      1017681
# 45  2006    840118      4279439       890676
# 46  2007    886654      4413668      1012563
# 47  2008    845734      4425314      1043321
# 48  2009    933918      4348068      1216377
# 49  2010    977778      4388386      1285492
# 50  2011    870741      4298178      1296000
# 51  2012    883406      4421352      1385352
# 52  2013    892372      4564840      1311875
# 53  2014    868094      4756771      1435741
# 54  2015    989354      5520736      1745804
# 55  2016    996263      5969811      2365110
# 56  2017   1054325      6254238      2571684

# %%
plt.hist(np_data['GrandCanyon'], facecolor='green', edgecolor='blue', bins=10)
plt.show()

# %%
plt.hist(np_data['GrandCanyon'], facecolor='green', edgecolor='blue', bins=10,cumulative=True)
plt.show()

# %% [markdown]
# ## Line plots

# %%
stock_data  = pd.read_csv('https://raw.githubusercontent.com/BadreeshShetty/Data-Visualization-using-Matplotlib/master/datasets/stocks.csv')

# %%
stock_data.head(3)
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198

# %%
#stock_data.to_csv('Stocks.csv',index=False)

# %%
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.head()
# Out:
#         Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0 2007-01-03  11.107141  38.869999  50.777351  251.001007  79.242500
# 1 2007-02-01  10.962033  39.250000  48.082939  224.949951  74.503204
# 2 2007-03-01  12.037377  41.700001  51.900383  229.309311  75.561348
# 3 2007-04-02  12.930043  41.560001  54.588032  235.925919  81.934280
# 4 2007-05-01  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
#fig = plt.figure(figsize=(10,6))

plt.figure(figsize=(10,6))

plt.plot(stock_data['Date'],stock_data['AAPL'],color='green')
plt.show()

# %%
fig = plt.figure(figsize=(10,6))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.05, 0.65, 0.5, 0.3])

ax1.set_title('AAPL vs IBM(inset)')

ax1.plot(stock_data['Date'],
         stock_data['AAPL'],
         color='green')

ax2.plot(stock_data['Date'],
         stock_data['IBM'], 
         color='blue')
plt.show()

# %% [markdown]
# #### subplots

# %%
# Figsize for width and height of plot
fig = plt.figure(figsize=(15,7))

fig.suptitle('Stock price comparison 2007-2017', 
             fontsize=20)

ax1 = fig.add_subplot(221)
ax1.set_title('MSFT')
ax1.plot(stock_data['Date'],stock_data['MSFT'], color='green')

ax2 = fig.add_subplot(222)
ax2.set_title('GOOG')
ax2.plot(stock_data['Date'],stock_data['GOOG'], color='purple')

ax3 = fig.add_subplot(223)
ax3.set_title('SBUX')
ax3.plot(stock_data['Date'],stock_data['SBUX'], color='magenta')

ax4 = fig.add_subplot(224)
ax4.set_title('ADBE')
ax4.plot(stock_data['Date'],stock_data['ADBE'], color='orange')

plt.show()

# %% [markdown]
# ## Stack plots

# %%
np_data.head(2)
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000

# %%
x = np_data['Year']

# %%
y = np.vstack([np_data['Badlands'], np_data['GrandCanyon'], np_data['BryceCanyon']])

# %%
y
# Out:
# array([[ 833300, 1044800, 1074000, 1079800, 1091300, 1094800, 1188700,
#         1194600, 1221300, 1303100, 1282000, 1274600, 1387900, 1205300,
#         1153200, 1210100, 1305400, 1234915,  858000,  952652, 1175952,
#         1030484, 1026981, 1113675,  950242, 1025630, 1174398, 1110040,
#         1237956, 1326475, 1518396, 1205297, 1179458, 1130459, 1075569,
#         1024705,  970696, 1021049,  950453, 1105824,  955469,  908898,
#          871034,  936030,  909146,  840118,  886654,  845734,  933918,
#          977778,  870741,  883406,  892372,  868094,  989354,  996263,
#         1054325],
#        [1253000, 1447400, 1539500, 1576600, 1689200, 1806000, 1804900,
#         1986300, 2192600, 2258200, 2402100, 2698300, 1909700, 1888600,
#         2625100, 2791600, 2627200, 2748642, 2131716, 2304973, 2472270,
#         2293127, 2248082, 2173584, 2711529, 3035787, 3513030, 3859886,
#         3966209, 3776685, 3886031, 4203545, 4575602, 4364316, 4557645,
#         4537703, 4791668, 4239682, 4575124, 4460228, 4104809, 4001974,
#         4124900, 4326234, 4401522, 4279439, 4413668, 4425314, 4348068,
#         4388386, 4298178, 4421352, 4564840, 4756771, 5520736, 5969811,
#         6254238],
#        [ 264800,  251000,  289500,  300300,  366800,  396600,  295000,
#          320800,  366900,  345900,  377800,  424830,  429700,  408800,
#          579200,  625600,  611500,  679260,  558095,  571541,  474092,
#          471517,  472633,  495104,  500782,  578018,  718342,  791348,
#          808045,  862659,  929067, 1018174, 1107951, 1028134,  994548,
#         1269600, 1174824, 1166331, 1081521, 1099275, 1068619,  886436,
#          903760,  987253, 1017681,  890676, 1012563, 1043321, 1216377,
#         1285492, 1296000, 1385352, 1311875, 1435741, 1745804, 2365110,
#         2571684]], dtype=int64)

# %%
# Labels for each stack
plt.figure(figsize=(15,7))
labels = ['Badlands', 'GrandCanyon', 'BryceCanyon']

# Colors for each stack
colors = ['brown', 'tomato', 'skyblue']

#  Similar to pandas df.plot.area()
plt.stackplot(x, y, labels=labels, colors=colors, edgecolor='black')

# Plots legend to the upperleft of Figure
plt.legend(loc=2)

plt.show()

# %% [markdown]
# ## Stem Plot

# %%
np_stem = np_data.copy()

# %%
1044800 - 833300
# Out:
# 211500

# %%
np_stem.head(3)
# Out:
#    Year  Badlands  GrandCanyon  BryceCanyon
# 0  1961    833300      1253000       264800
# 1  1962   1044800      1447400       251000
# 2  1963   1074000      1539500       289500

# %%
np_stem[['Badlands', 'GrandCanyon','BryceCanyon']] = np_data[['Badlands', 'GrandCanyon','BryceCanyon']].diff()
np_stem
# Out:
#     Year  Badlands  GrandCanyon  BryceCanyon
# 0   1961       NaN          NaN          NaN
# 1   1962  211500.0     194400.0     -13800.0
# 2   1963   29200.0      92100.0      38500.0
# 3   1964    5800.0      37100.0      10800.0
# 4   1965   11500.0     112600.0      66500.0
# 5   1966    3500.0     116800.0      29800.0
# 6   1967   93900.0      -1100.0    -101600.0
# 7   1968    5900.0     181400.0      25800.0
# 8   1969   26700.0     206300.0      46100.0
# 9   1970   81800.0      65600.0     -21000.0
# 10  1971  -21100.0     143900.0      31900.0
# 11  1972   -7400.0     296200.0      47030.0
# 12  1973  113300.0    -788600.0       4870.0
# 13  1974 -182600.0     -21100.0     -20900.0
# 14  1975  -52100.0     736500.0     170400.0
# 15  1976   56900.0     166500.0      46400.0
# 16  1977   95300.0    -164400.0     -14100.0
# 17  1978  -70485.0     121442.0      67760.0
# 18  1979 -376915.0    -616926.0    -121165.0
# 19  1980   94652.0     173257.0      13446.0
# 20  1981  223300.0     167297.0     -97449.0
# 21  1982 -145468.0    -179143.0      -2575.0
# 22  1983   -3503.0     -45045.0       1116.0
# 23  1984   86694.0     -74498.0      22471.0
# 24  1985 -163433.0     537945.0       5678.0
# 25  1986   75388.0     324258.0      77236.0
# 26  1987  148768.0     477243.0     140324.0
# 27  1988  -64358.0     346856.0      73006.0
# 28  1989  127916.0     106323.0      16697.0
# 29  1990   88519.0    -189524.0      54614.0
# 30  1991  191921.0     109346.0      66408.0
# 31  1992 -313099.0     317514.0      89107.0
# 32  1993  -25839.0     372057.0      89777.0
# 33  1994  -48999.0    -211286.0     -79817.0
# 34  1995  -54890.0     193329.0     -33586.0
# 35  1996  -50864.0     -19942.0     275052.0
# 36  1997  -54009.0     253965.0     -94776.0
# 37  1998   50353.0    -551986.0      -8493.0
# 38  1999  -70596.0     335442.0     -84810.0
# 39  2000  155371.0    -114896.0      17754.0
# 40  2001 -150355.0    -355419.0     -30656.0
# 41  2002  -46571.0    -102835.0    -182183.0
# 42  2003  -37864.0     122926.0      17324.0
# 43  2004   64996.0     201334.0      83493.0
# 44  2005  -26884.0      75288.0      30428.0
# 45  2006  -69028.0    -122083.0    -127005.0
# 46  2007   46536.0     134229.0     121887.0
# 47  2008  -40920.0      11646.0      30758.0
# 48  2009   88184.0     -77246.0     173056.0
# 49  2010   43860.0      40318.0      69115.0
# 50  2011 -107037.0     -90208.0      10508.0
# 51  2012   12665.0     123174.0      89352.0
# 52  2013    8966.0     143488.0     -73477.0
# 53  2014  -24278.0     191931.0     123866.0
# 54  2015  121260.0     763965.0     310063.0
# 55  2016    6909.0     449075.0     619306.0
# 56  2017   58062.0     284427.0     206574.0

# %%
plt.figure(figsize=(15,11))

plt.suptitle('Change in Number of Visitors', y=0.94)

plt.subplot(311)
plt.stem(np_stem['Year'],np_stem['Badlands'])#,markerfmt = 'b_',linefmt = 'r--',basefmt = 'g:')
plt.title('GrandCanyon')

plt.subplot(312)
plt.stem(np_stem['Year'],
         np_stem['GrandCanyon'],
         markerfmt = 'b_',
         linefmt = 'r--',
         basefmt = 'g:')
plt.title('Badlands')

plt.subplot(313)
plt.stem(np_stem['Year'],
         np_stem['BryceCanyon'],
         markerfmt = 'b_',
         linefmt = 'r--',
         basefmt = 'g:')
plt.title('BryceCanyon')

plt.show()
# Out:
# C:\Users\skesh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#
# C:\Users\skesh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#
# C:\Users\skesh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
